# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
x=[1,2,3,4,5,6,7]
y=[20,40,30,60,20,10,65]
df=pd.DataFrame({"Days":x,"No of people":y})

# %%
df
# Out:
#    Days  No of people
# 0     1            20
# 1     2            40
# 2     3            30
# 3     4            60
# 4     5            20
# 5     6            10
# 6     7            65

# %%
sns.lineplot(x="Days",y="No of people",data=df)
# Out:
# <Axes: xlabel='Days', ylabel='No of people'>

# %%
ds=sns.load_dataset("tips")

# %%
ds.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lineplot(x="day",y="total_bill",data=ds,hue="sex",style="time",palette="flare")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
import numpy as np

# %%
df=sns.load_dataset("titanic")
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
sns.barplot(x="who",y="fare",data=df,color="magenta")
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %%
# "deep", "muted", "bright", "pastel", "dark", "colorblind","spring"

sns.barplot(x="who",y="fare",data=df,hue="sex",palette="spring",saturation=0.2,errorbar=('ci', False))
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %%
from numpy import mean
sns.barplot(x="who",y="fare",data=df,estimator=mean)
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %%
sns.relplot(x="total_bill",y="tip",data=ds,hue="smoker",style="size")
# Out:
# /Users/sharafunneesapp/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
ds['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.set(font_scale=2)
sns.relplot(x="total_bill",y="tip",data=ds,kind="line",height=5,aspect=4)
# Out:
# /Users/sharafunneesapp/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
