# %%
import pandas as pd
dataset = pd.read_csv("Crop_recommendation.csv")
dataset
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall   label  Unnamed: 8  Unnamed: 9
# 0     202.935536    rice         NaN         NaN
# ...

# %%
data1=pd.Series([1,2,3,4,5])
data1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data2=pd.DataFrame({
    "roll":[101,102,103,104],
    "name":["nisha","nilu","ammu","rafeek"],
    "mark":[66,77,34,89],
    
})
data2
# Out:
#    roll    name  mark
# 0   101   nisha    66
# 1   102    nilu    77
# 2   103    ammu    34
# 3   104  rafeek    89

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    4 non-null      int64
#  1   name    4 non-null      object
#  2   mark    4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
data2.describe()
# Out:
#              roll       mark
# count    4.000000   4.000000
# mean   102.500000  66.500000
# std      1.290994  23.614967
# min    101.000000  34.000000
# 25%    101.750000  58.000000
# 50%    102.500000  71.500000
# 75%    103.250000  80.000000
# max    104.000000  89.000000

# %%
data2["roll"]
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# Name: roll, dtype: int64

# %%
data2["mark"].mean()
# Out:
# 66.5

# %%
res=data2["mark"]>70
data2[res]
# Out:
#    roll    name  mark
# 1   102    nilu    77
# 3   104  rafeek    89

# %%
data2[0:2]
# Out:
#    roll   name  mark
# 0   101  nisha    66
# 1   102   nilu    77

# %%
data2["name"][0:2]
# Out:
# 0    nisha
# 1     nilu
# Name: name, dtype: object

# %%
dataset.columns
# Out:
# Index(['Nitrogen', 'phosphorus', 'potassium', 'temperature', 'humidity', 'ph',
#        'rainfall', 'label', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
dataset['Nitrogen'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2195    False
# 2196    False
# 2197    False
# 2198    False
# 2199    False
# Name: Nitrogen, Length: 2200, dtype: bool

# %%
dataset['Nitrogen'].value_counts()
# Out:
# Nitrogen
# 22     44
# 40     44
# 27     42
# 39     41
# 31     41
#        ..
# 136     2
# 139     1
# 135     1
# 130     1
# 46      1
# Name: count, Length: 137, dtype: int64

# %%
import numpy as np
data=pd.DataFrame(np.arange(15).reshape(3,5))
data
# Out:
#     0   1   2   3   4
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14

# %%
a=pd.Series(10,index=["a","b","c","d","e"])
a
# Out:
# a    10
# b    10
# c    10
# d    10
# e    10
# dtype: int64

# %%
coursera=pd.read_csv("CourseraDataset-Unclean.csv")

# %%
coursera
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3       Distribución digital de la música independiente     NaN
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 9590                                   Power Onboarding     4.1
# 9591     Implementing Parent Feedback with Google Forms     4.9
# 9592                        "Making" Progress Teach-Out     4.2
# 9593  Use Microsoft PowerPoint to Create a Visual Sc...     4.5
# 9594  Créer du contenu pour les réseaux sociaux avec...     NaN
#
#                Level                      Duration           Schedule  \
# 0     Beginner level      20 hours (approximately)  Flexible schedule
# ...

# %%
coursera['Rating'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 9590    False
# 9591    False
# 9592    False
# 9593    False
# 9594     True
# Name: Rating, Length: 9595, dtype: bool

# %%
coursera['Rating'].isnull().value_counts()
# Out:
# Rating
# False    8156
# True     1439
# Name: count, dtype: int64

# %%
coursera.loc[coursera['Rating'].isna(),'Rating']=20
coursera['Rating']
# Out:
# 0        4.8
# 1        4.4
# 2        4.5
# 3       20.0
# 4        4.8
#         ...
# 9590     4.1
# 9591     4.9
# 9592     4.2
# 9593     4.5
# 9594    20.0
# Name: Rating, Length: 9595, dtype: float64

# %%
coursera.columns
# Out:
# Index(['Course Title', 'Rating', 'Level', 'Duration', 'Schedule', 'Review',
#        'What you will learn', 'Skill gain', 'Modules', 'Instructor',
#        'Offered By', 'Keyword', 'Course Url'],
#       dtype='object')

# %%
coursera['Keyword'].dropna()
# Out:
# 0       Arts and Humanities
# 1       Arts and Humanities
# 2       Arts and Humanities
# 3       Arts and Humanities
# 4       Arts and Humanities
#                ...
# 9590        Social Sciences
# 9591        Social Sciences
# 9592        Social Sciences
# 9593        Social Sciences
# 9594        Social Sciences
# Name: Keyword, Length: 9595, dtype: object

# %%
coursera.head(10)
# Out:
#                                         Course Title  Rating  \
# 0                                  Fashion as Design     4.8
# 1                             Modern American Poetry     4.4
# 2                          Pixel Art for Video Games     4.5
# 3    Distribución digital de la música independiente    20.0
# 4  The Blues: Understanding and Performing an Ame...     4.8
# 5                       So You Think You Know Tango?     4.6
# 6                         The Politics of Skepticism     4.5
# 7                       Становлення сучасної України    20.0
# 8         Exploring Beethoven's Piano Sonatas Part 4     4.9
# 9                                           悖论：思维的魔方     4.8
#
#                 Level                      Duration           Schedule  \
# 0      Beginner level      20 hours (approximately)  Flexible schedule
# 1      Beginner level  Approx. 34 hours to complete  Flexible schedule
# 2      Beginner level       9 hours (approximately)  Flexible schedule
# ...

# %%
coursera['Rating'].fillna(coursera['Rating'].mean())
# Out:
# 0        4.8
# 1        4.4
# 2        4.5
# 3       20.0
# 4        4.8
#         ...
# 9590     4.1
# 9591     4.9
# 9592     4.2
# 9593     4.5
# 9594    20.0
# Name: Rating, Length: 9595, dtype: float64

# %%
coursera[1:6]
# Out:
#                                         Course Title  Rating           Level  \
# 1                             Modern American Poetry     4.4  Beginner level
# 2                          Pixel Art for Video Games     4.5  Beginner level
# 3    Distribución digital de la música independiente    20.0  Beginner level
# 4  The Blues: Understanding and Performing an Ame...     4.8  Beginner level
# 5                       So You Think You Know Tango?     4.6  Beginner level
#
#                        Duration           Schedule       Review  \
# 1  Approx. 34 hours to complete  Flexible schedule  100 reviews
# 2       9 hours (approximately)  Flexible schedule  227 reviews
# 3   Approx. 8 hours to complete  Flexible schedule          NaN
# 4  Approx. 11 hours to complete  Flexible schedule  582 reviews
# 5   Approx. 5 hours to complete  Flexible schedule  107 reviews
#
#                                  What you will learn  \
# 1                                                NaN
# ...

# %%
coursera[1:3]
# Out:
#                 Course Title  Rating           Level  \
# 1     Modern American Poetry     4.4  Beginner level
# 2  Pixel Art for Video Games     4.5  Beginner level
#
#                        Duration           Schedule       Review  \
# 1  Approx. 34 hours to complete  Flexible schedule  100 reviews
# 2       9 hours (approximately)  Flexible schedule  227 reviews
#
#   What you will learn Skill gain  \
# 1                 NaN         []
# 2                 NaN         []
#
#                                              Modules  \
# 1  ['Orientation', 'Module 1', 'Module 2', 'Modul...
# 2  ['Week 1: Introduction to Pixel Art', 'Week 2:...
#
#                                Instructor  \
# 1                         ['Cary Nelson']
# 2  ['Andrew Dennis', 'Ricardo Guimaraes']
#
#                                        Offered By              Keyword  \
# 1  ['University of Illinois at Urbana-Champaign']  Arts and Humanities
# ...

# %%
coursera.iloc[1:6,1:3]
# Out:
#    Rating           Level
# 1     4.4  Beginner level
# 2     4.5  Beginner level
# 3    20.0  Beginner level
# 4     4.8  Beginner level
# 5     4.6  Beginner level

# %%
coursera.loc[1:5,:]
# Out:
#                                         Course Title  Rating           Level  \
# 1                             Modern American Poetry     4.4  Beginner level
# 2                          Pixel Art for Video Games     4.5  Beginner level
# 3    Distribución digital de la música independiente    20.0  Beginner level
# 4  The Blues: Understanding and Performing an Ame...     4.8  Beginner level
# 5                       So You Think You Know Tango?     4.6  Beginner level
#
#                        Duration           Schedule       Review  \
# 1  Approx. 34 hours to complete  Flexible schedule  100 reviews
# 2       9 hours (approximately)  Flexible schedule  227 reviews
# 3   Approx. 8 hours to complete  Flexible schedule          NaN
# 4  Approx. 11 hours to complete  Flexible schedule  582 reviews
# 5   Approx. 5 hours to complete  Flexible schedule  107 reviews
#
#                                  What you will learn  \
# 1                                                NaN
# ...

# %%
coursera.iloc[1,1]=250

# %%
coursera
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                                   100   250.0
# 2                                                   100   100.0
# 3                                                   100   100.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 9590                                   Power Onboarding     4.1
# 9591     Implementing Parent Feedback with Google Forms     4.9
# 9592                        "Making" Progress Teach-Out     4.2
# 9593  Use Microsoft PowerPoint to Create a Visual Sc...     4.5
# 9594  Créer du contenu pour les réseaux sociaux avec...    20.0
#
#                Level                      Duration           Schedule  \
# 0     Beginner level      20 hours (approximately)  Flexible schedule
# ...

# %%
coursera.drop(coursera.index[1])
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 2                                                   100   100.0
# 3                                                   100   100.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# 5                          So You Think You Know Tango?     4.6
# ...                                                 ...     ...
# 9590                                   Power Onboarding     4.1
# 9591     Implementing Parent Feedback with Google Forms     4.9
# 9592                        "Making" Progress Teach-Out     4.2
# 9593  Use Microsoft PowerPoint to Create a Visual Sc...     4.5
# 9594  Créer du contenu pour les réseaux sociaux avec...    20.0
#
#                Level                      Duration           Schedule  \
# 0     Beginner level      20 hours (approximately)  Flexible schedule
# ...

# %%
coursera.drop(coursera.columns[2],axis=1)
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                                   100   250.0
# 2                                                   100   100.0
# 3                                                   100   100.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 9590                                   Power Onboarding     4.1
# 9591     Implementing Parent Feedback with Google Forms     4.9
# 9592                        "Making" Progress Teach-Out     4.2
# 9593  Use Microsoft PowerPoint to Create a Visual Sc...     4.5
# 9594  Créer du contenu pour les réseaux sociaux avec...    20.0
#
#                           Duration           Schedule         Review  \
# 0         20 hours (approximately)  Flexible schedule  2,813 reviews
# ...

# %%
coursera.drop(["Skill gain","Keyword"],axis=1)
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                                   100   250.0
# 2                                                   100   100.0
# 3                                                   100   100.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 9590                                   Power Onboarding     4.1
# 9591     Implementing Parent Feedback with Google Forms     4.9
# 9592                        "Making" Progress Teach-Out     4.2
# 9593  Use Microsoft PowerPoint to Create a Visual Sc...     4.5
# 9594  Créer du contenu pour les réseaux sociaux avec...    20.0
#
#                Level                      Duration           Schedule  \
# 0     Beginner level      20 hours (approximately)  Flexible schedule
# ...

# %%
df=pd.Series((101,"nisha",66),index=["roll","name","mark"])
df
# Out:
# roll      101
# name    nisha
# mark       66
# dtype: object

# %%
df1={0:[pd.Series([1,2,3])],1:[pd.Series([4,5,6])]}
df1
# Out:
# {0: [0    1
#   1    2
#   2    3
#   dtype: int64],
#  1: [0    4
#   1    5
#   2    6
#   dtype: int64]}

# %%
ds=pd.DataFrame(index=range(3),columns=range(5))
ds
# Out:
#      0    1    2    3    4
# 0  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN

# %%
ds.isna()
# Out:
#       0     1     2     3     4
# 0  True  True  True  True  True
# 1  True  True  True  True  True
# 2  True  True  True  True  True

# %%
ds.fillna(10)
# Out:
#     0   1   2   3   4
# 0  10  10  10  10  10
# 1  10  10  10  10  10
# 2  10  10  10  10  10

# %%
ds[1].count()
# Out:
# 0

# %%
df=pd.Series([3,4,9,8,8,8,8, 0])
df.sort_values()
# Out:
# 7    0
# 0    3
# 1    4
# 3    8
# 4    8
# 5    8
# 6    8
# 2    9
# dtype: int64

# %%
ds
# Out:
#      0    1    2    3    4
# 0  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN

# %%
df1={3:"nisha",8:"ammu"}
res=df.map(df1)

# %%
res.isnull()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# dtype: bool

# %%
res.dropna()
# Out:
# 0    nisha
# 3     ammu
# 4     ammu
# 5     ammu
# 6     ammu
# dtype: object

# %%
res.fillna("nilu")
# Out:
# 0    nisha
# 1     nilu
# 2     nilu
# 3     ammu
# 4     ammu
# 5     ammu
# 6     ammu
# 7     nilu
# dtype: object

# %%
coursera
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                                   100   250.0
# 2                                                   100   100.0
# 3                                                   100   100.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 9590                                   Power Onboarding     4.1
# 9591     Implementing Parent Feedback with Google Forms     4.9
# 9592                        "Making" Progress Teach-Out     4.2
# 9593  Use Microsoft PowerPoint to Create a Visual Sc...     4.5
# 9594  Créer du contenu pour les réseaux sociaux avec...    20.0
#
#                Level                      Duration           Schedule  \
# 0     Beginner level      20 hours (approximately)  Flexible schedule
# ...

# %%
coursera['Rating']=coursera['Rating']*2
coursera
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design    19.2
# 1                                                   100  1000.0
# 2                                                   100   400.0
# 3                                                   100   400.0
# 4     The Blues: Understanding and Performing an Ame...    19.2
# ...                                                 ...     ...
# 9590                                   Power Onboarding    16.4
# 9591     Implementing Parent Feedback with Google Forms    19.6
# 9592                        "Making" Progress Teach-Out    16.8
# 9593  Use Microsoft PowerPoint to Create a Visual Sc...    18.0
# 9594  Créer du contenu pour les réseaux sociaux avec...    80.0
#
#                Level                      Duration           Schedule  \
# 0     Beginner level      20 hours (approximately)  Flexible schedule
# ...

# %%
coursera.drop(coursera.columns[2:5],axis=1)
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design    19.2
# 1                                                   100  1000.0
# 2                                                   100   400.0
# 3                                                   100   400.0
# 4     The Blues: Understanding and Performing an Ame...    19.2
# ...                                                 ...     ...
# 9590                                   Power Onboarding    16.4
# 9591     Implementing Parent Feedback with Google Forms    19.6
# 9592                        "Making" Progress Teach-Out    16.8
# 9593  Use Microsoft PowerPoint to Create a Visual Sc...    18.0
# 9594  Créer du contenu pour les réseaux sociaux avec...    80.0
#
#              Review                                What you will learn  \
# 0     2,813 reviews                                                NaN
# ...

# %%
res=coursera['Rating'].between(70,90)
coursera[res]
# Out:
#                                            Course Title  Rating  \
# 7                          Становлення сучасної України    80.0
# 16        Create your UX portfolio with Adobe Portfolio    80.0
# 20                              Cultura Maya en Yucatán    80.0
# 22    Herencia negra, aplicación de ritmos afroperuanos    80.0
# 23                      Storytelling y medios digitales    80.0
# ...                                                 ...     ...
# 9582         Housing Justice: A View from Indian Cities    80.0
# 9584       R Programming and Tidyverse Capstone Project    80.0
# 9586  Using Microsoft PowerPoint to Create a Choice ...    80.0
# 9587  India-US Relations: Geopolitics, Culture, and ...    80.0
# 9594  Créer du contenu pour les réseaux sociaux avec...    80.0
#
#                Level                      Duration           Schedule Review  \
# 7     Beginner level  Approx. 23 hours to complete  Flexible schedule    NaN
# ...

# %%
res=coursera['Rating'].isin([1000,400])
coursera[res]
# Out:
#   Course Title  Rating Level Duration Schedule Review What you will learn  \
# 1          100  1000.0   100      100      100    100                 100
# 2          100   400.0   100      100      100    100                 100
# 3          100   400.0   100      100      100    100                 100
#
#   Skill gain Modules Instructor Offered By Keyword Course Url
# 1        100     100        100        100     100        100
# 2        100     100        100        100     100        100
# 3        100     100        100        100     100        100

# %%
course=pd.read_csv("Crop_recommendation.csv")

# %%
course.head(10)
# Out:
#    Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0        90          42         43    20.879744  82.002744  6.502985
# 1        85          58         41    21.770462  80.319644  7.038096
# 2        60          55         44    23.004459  82.320763  7.840207
# 3        74          35         40    26.491096  80.158363  6.980401
# 4        78          42         42    20.130175  81.604873  7.628473
# 5        69          37         42    23.058049  83.370118  7.073454
# 6        69          55         38    22.708838  82.639414  5.700806
# 7        94          53         40    20.277744  82.894086  5.718627
# 8        89          54         38    24.515881  83.535216  6.685346
# 9        68          58         38    23.223974  83.033227  6.336254
#
#      rainfall label  Unnamed: 8  Unnamed: 9
# 0  202.935536  rice         NaN         NaN
# 1  226.655537  rice         NaN         NaN
# 2  263.964248  rice         NaN         NaN
# ...

# %%
course['potassium'].mean()
# Out:
# 48.14909090909091

# %% [raw]
# course.loc[1:5,'Nitrogen]

# %%
course
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall   label  Unnamed: 8  Unnamed: 9
# 0     202.935536    rice         NaN         NaN
# ...

# %%
course.loc[1:5,'Nitrogen']
# Out:
# 1    85
# 2    60
# 3    74
# 4    78
# 5    69
# Name: Nitrogen, dtype: int64

# %%
course.loc[2:6,"Nitrogen":"ph"]
# Out:
#    Nitrogen  phosphorus  potassium  temperature   humidity        ph
# 2        60          55         44    23.004459  82.320763  7.840207
# 3        74          35         40    26.491096  80.158363  6.980401
# 4        78          42         42    20.130175  81.604873  7.628473
# 5        69          37         42    23.058049  83.370118  7.073454
# 6        69          55         38    22.708838  82.639414  5.700806

# %%
course['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
data=course.groupby(['label'])
data

# %%
data.describe()
# Out:
#             Nitrogen                                                          \
#                count    mean        std    min     25%    50%     75%    max
# label
# apple          100.0   20.80  11.863704    0.0   10.00   24.0   30.00   40.0
# banana         100.0  100.23  11.107241   80.0   92.00  100.5  108.25  120.0
# blackgram      100.0   40.02  12.664258   20.0   28.75   41.0   52.00   60.0
# chickpea       100.0   40.09  12.150649   20.0   30.00   39.0   52.00   60.0
# coconut        100.0   21.98  11.761931    0.0   13.75   24.0   31.00   40.0
# coffee         100.0  101.20  12.345203   80.0   89.00  103.0  112.00  120.0
# cotton         100.0  117.77  11.628817  100.0  107.75  117.0  127.50  140.0
# grapes         100.0   23.18  12.466829    0.0   11.75   24.0   35.00   40.0
# jute           100.0   78.40  10.968274   60.0   70.00   78.0   88.25  100.0
# kidneybeans    100.0   20.75  10.834266    0.0   11.75   22.0   28.00   40.0
# ...

# %%
r=course.dropna(axis=1)
r
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall   label
# 0     202.935536    rice
# 1     226.655537    rice
# ...

# %%
res=r.groupby(['label'])

# %% [raw]
# res

# %%
res

# %%
res.describe()
# Out:
#             Nitrogen                                                          \
#                count    mean        std    min     25%    50%     75%    max
# label
# apple          100.0   20.80  11.863704    0.0   10.00   24.0   30.00   40.0
# banana         100.0  100.23  11.107241   80.0   92.00  100.5  108.25  120.0
# blackgram      100.0   40.02  12.664258   20.0   28.75   41.0   52.00   60.0
# chickpea       100.0   40.09  12.150649   20.0   30.00   39.0   52.00   60.0
# coconut        100.0   21.98  11.761931    0.0   13.75   24.0   31.00   40.0
# coffee         100.0  101.20  12.345203   80.0   89.00  103.0  112.00  120.0
# cotton         100.0  117.77  11.628817  100.0  107.75  117.0  127.50  140.0
# grapes         100.0   23.18  12.466829    0.0   11.75   24.0   35.00   40.0
# jute           100.0   78.40  10.968274   60.0   70.00   78.0   88.25  100.0
# kidneybeans    100.0   20.75  10.834266    0.0   11.75   22.0   28.00   40.0
# ...

# %%
res.mean()
# Out:
#              Nitrogen  phosphorus  potassium  temperature   humidity  \
# label
# apple           20.80      134.22     199.89    22.630942  92.333383
# banana         100.23       82.01      50.05    27.376798  80.358123
# blackgram       40.02       67.47      19.24    29.973340  65.118426
# chickpea        40.09       67.79      79.92    18.872847  16.860439
# coconut         21.98       16.93      30.59    27.409892  94.844272
# coffee         101.20       28.74      29.94    25.540477  58.869846
# cotton         117.77       46.24      19.56    23.988958  79.843474
# grapes          23.18      132.53     200.11    23.849575  81.875228
# jute            78.40       46.86      39.99    24.958376  79.639864
# kidneybeans     20.75       67.54      20.05    20.115085  21.605357
# lentil          18.77       68.36      19.41    24.509052  64.804785
# maize           77.76       48.44      19.79    22.389204  65.092249
# ...

# %%
res.get_group('mango')
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 1100         2          40         27    29.737700  47.548852  5.954627
# 1101        39          24         31    33.556956  53.729798  4.757115
# 1102        21          26         27    27.003155  47.675254  5.699587
# 1103        25          22         25    33.561502  45.535566  5.977414
# 1104         0          21         32    35.898556  54.259642  6.430139
# ...        ...         ...        ...          ...        ...       ...
# 1195        19          38         26    31.484517  48.779263  4.525722
# 1196        21          21         30    27.698193  51.415932  5.403908
# 1197        22          18         33    30.412358  52.481006  6.621624
# 1198        31          20         30    32.177520  54.013527  6.207496
# 1199        18          26         31    32.611261  47.749165  5.418475
#
#         rainfall  label
# 1100   90.095869  mango
# 1101   98.675276  mango
# 1102   95.851183  mango
# ...

# %%
course
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall   label  Unnamed: 8  Unnamed: 9
# 0     202.935536    rice         NaN         NaN
# ...

# %%
course.dropna(axis=1)
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall   label
# 0     202.935536    rice
# 1     226.655537    rice
# ...

# %%
course.loc[2:6]
# Out:
#    Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 2        60          55         44    23.004459  82.320763  7.840207
# 3        74          35         40    26.491096  80.158363  6.980401
# 4        78          42         42    20.130175  81.604873  7.628473
# 5        69          37         42    23.058049  83.370118  7.073454
# 6        69          55         38    22.708838  82.639414  5.700806
#
#      rainfall label  Unnamed: 8  Unnamed: 9
# 2  263.964248  rice         NaN         NaN
# 3  242.864034  rice         NaN         NaN
# 4  262.717340  rice         NaN         NaN
# 5  251.055000  rice         NaN         NaN
# 6  271.324860  rice         NaN         NaN

# %%
course.loc[2:6],["Nitrogen"]
# Out:
# (   Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
#  2        60          55         44    23.004459  82.320763  7.840207
#  3        74          35         40    26.491096  80.158363  6.980401
#  4        78          42         42    20.130175  81.604873  7.628473
#  5        69          37         42    23.058049  83.370118  7.073454
#  6        69          55         38    22.708838  82.639414  5.700806
#
#       rainfall label  Unnamed: 8  Unnamed: 9
#  2  263.964248  rice         NaN         NaN
#  3  242.864034  rice         NaN         NaN
#  4  262.717340  rice         NaN         NaN
#  5  251.055000  rice         NaN         NaN
#  6  271.324860  rice         NaN         NaN  ,
#  ['Nitrogen'])

# %%
course.iloc[2:6,3]
# Out:
# 2    23.004459
# 3    26.491096
# 4    20.130175
# 5    23.058049
# Name: temperature, dtype: float64

# %%
course.iloc[[2,3],[3,6]]
# Out:
#    temperature    rainfall
# 2    23.004459  263.964248
# 3    26.491096  242.864034

# %%
res=course.groupby(['label'])

# %%
res.mean()
# Out:
#              Nitrogen  phosphorus  potassium  temperature   humidity  \
# label
# apple           20.80      134.22     199.89    22.630942  92.333383
# banana         100.23       82.01      50.05    27.376798  80.358123
# blackgram       40.02       67.47      19.24    29.973340  65.118426
# chickpea        40.09       67.79      79.92    18.872847  16.860439
# coconut         21.98       16.93      30.59    27.409892  94.844272
# coffee         101.20       28.74      29.94    25.540477  58.869846
# cotton         117.77       46.24      19.56    23.988958  79.843474
# grapes          23.18      132.53     200.11    23.849575  81.875228
# jute            78.40       46.86      39.99    24.958376  79.639864
# kidneybeans     20.75       67.54      20.05    20.115085  21.605357
# lentil          18.77       68.36      19.41    24.509052  64.804785
# maize           77.76       48.44      19.79    22.389204  65.092249
# ...

# %%
course.count()
# Out:
# Nitrogen       2200
# phosphorus     2200
# potassium      2200
# temperature    2200
# humidity       2200
# ph             2200
# rainfall       2200
# label          2200
# Unnamed: 8        0
# Unnamed: 9        0
# dtype: int64

# %%
r=res['Nitrogen'].agg([min,max])
r
# Out:
#              min  max
# label
# apple          0   40
# banana        80  120
# blackgram     20   60
# chickpea      20   60
# coconut        0   40
# coffee        80  120
# cotton       100  140
# grapes         0   40
# jute          60  100
# kidneybeans    0   40
# lentil         0   40
# maize         60  100
# mango          0   40
# mothbeans      0   40
# mungbean       0   40
# muskmelon     80  120
# orange         0   40
# papaya        31   70
# pigeonpeas     0   40
# pomegranate    0   40
# rice          60   99
# watermelon    80  120
